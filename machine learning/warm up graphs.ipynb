# %% [markdown]
# # NATS3100: Practical week 1

# %% [markdown]
# The aim of this weeks tasks is:
#
# * To get you started with Python and Jupyter notebooks
# * Learn the difference between (i) supervised and unsupervised learning, and (ii) regression and classification
#
#
# To complete this practical you should work through the tasks below and show how you completed them by
# documenting the code in an Jupyter notebook
#
# Jupyter notebooks have become an integral part in science to write Python programs that can be shared with others, in particular in the field of data science. I have uploaded one articles about Jupyter to Minerva describing the increased popularity of Jupyter notebooks. There are also two videos (Jupyter1.mp4 and Jupyter2.mp4) you can watch to get a basic introduction to how to install Jupyter using Anaconda, and how to use Jupyter notebooks. Use markdown cells to write text with full sentences around your Python code to clearly state what you are doing. Use the help command to find out more about each Python command. I also uploaded a Jupyter book about Python, which I created for NATS2100.
#
# **Tasks:**
#
# 1. Generate 11 equally spaced values of x between 0 and 1 using the np.linespace or np.arange command from the numpy module. For each x value, calculate a y value obeying y = 2x. Plot x against y using the plt.plot command from the matplotlib.pyplot module
#
# 2. Generate 1000 uniformly distributed random numbers between 0 and 10 using the np.random.uniform command.
# Plot a histogram of these numbers with 50 bins using the plt.hist command
#
# 3. Using a mean of 1 and a standard deviation of 2, generate 100 Normally-distributed numbers using the
# np.random.normal command. Find the sample mean and standard deviation of this generated sample using the
# np.mean and np.std commands.
#
# 4. Write a program to compute the range of $R$ of a projectile launched with a velocity $v$ at an angle $\theta$ to the horizontal:
# $$
# R=(v^2/g)\sin(2\theta)
# $$
# where $g$ is the acceleration due to gravity ($g=9.81ms^{-2}$). For a fixed velocity velocity, write out the range $R$ for a series of angles $\theta$ to numerically determine the angle to maximise the range. Calculate this angle analytically.
#
# 5. Explain in your own words the distinctions between (i) supervised and unsupervised learning; and (ii)
# regression and classification.
#
# 6. Write a short (no more than 1 paragraph) description of where a statistical model is used in the real
# world. You may choose your own example or one from the notes. Is this supervised or unsupervised?
# Regression of classification? What tasks are being performed: prediction, inference or decisions?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.misc import derivative
x=np.linspace(0,1,11)
def Y_value(x):
    return (2*x)


plt.plot(x,Y_value(x))
plt.show()

# %%
random_no=np.random.uniform(0,10,1000)
bins=50
plt.hist(random_no, bins=bins)
# Out:
# (array([17., 17., 18., 13., 20., 22., 17., 11., 21., 27., 22., 17., 22.,
#         20., 18., 24., 27., 20., 23., 18., 23., 25., 30., 25., 29., 17.,
#         24., 20., 19., 21., 19., 24., 13., 18., 20., 13., 15., 13., 22.,
#         19., 12., 16., 17., 18., 12., 30., 29., 22., 18., 23.]),
#  array([6.68498242e-04, 2.00148303e-01, 3.99628108e-01, 5.99107913e-01,
#         7.98587719e-01, 9.98067524e-01, 1.19754733e+00, 1.39702713e+00,
#         1.59650694e+00, 1.79598674e+00, 1.99546655e+00, 2.19494635e+00,
#         2.39442616e+00, 2.59390596e+00, 2.79338577e+00, 2.99286557e+00,
#         3.19234538e+00, 3.39182518e+00, 3.59130499e+00, 3.79078479e+00,
#         3.99026460e+00, 4.18974440e+00, 4.38922421e+00, 4.58870402e+00,
#         4.78818382e+00, 4.98766363e+00, 5.18714343e+00, 5.38662324e+00,
#         5.58610304e+00, 5.78558285e+00, 5.98506265e+00, 6.18454246e+00,
#         6.38402226e+00, 6.58350207e+00, 6.78298187e+00, 6.98246168e+00,
# ...

# %%
random_normal=np.random.normal(1,2,100)
print(np.mean(random_normal))
print(np.std(random_normal))
# Out:
# 1.2435104693786274
# 1.7242898360345065

# %%
def R_range(theta):
    return ((50**2/9.81)*np.sin(2*theta))
theta=np.linspace(0,90,900)
plt.plot(theta,R_range(theta))
derivative(R_range,2.36)
# Out:
# 1.7636630314703226
